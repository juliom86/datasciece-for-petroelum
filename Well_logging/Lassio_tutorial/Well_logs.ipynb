# %% [markdown]
# # Perfiles pozo utilizando la libreria Lassio

# %% [markdown]
# ## Importo librerias

# %%
import pandas as pd
import lasio
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exploro y analizo los datos

# %%
las = lasio.read('15-9-19_SR_COMP.LAS')

# %%
df = las.df()

# %%
df.head()
# Out:
#                  AC     CALI     DEN       GR      NEU    RDEP    RMED
# DEPT
# 3615.4340   95.7952  12.7249  2.3429  54.8754  44.5742  0.8941  0.8359
# 3615.5864   94.2267  12.5961  2.3528  53.5158  62.1103  0.7367  0.8028
# 3615.7388  101.3254  13.7632  2.3170  48.9803  71.9087  0.6423  0.7958
# 3615.8912   99.5672  14.3249  2.2585  36.6762  44.8988  0.6571  0.7929
# 3616.0436  100.5965  11.1429  2.2108  40.4632  49.5744  0.7442  0.7940

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#         DEPT        AC     CALI     DEN       GR      NEU    RDEP    RMED
# 0  3615.4340   95.7952  12.7249  2.3429  54.8754  44.5742  0.8941  0.8359
# 1  3615.5864   94.2267  12.5961  2.3528  53.5158  62.1103  0.7367  0.8028
# 2  3615.7388  101.3254  13.7632  2.3170  48.9803  71.9087  0.6423  0.7958
# 3  3615.8912   99.5672  14.3249  2.2585  36.6762  44.8988  0.6571  0.7929
# 4  3616.0436  100.5965  11.1429  2.2108  40.4632  49.5744  0.7442  0.7940

# %%
df.rename(columns = {'DEPT' : 'DEPTH'}, inplace = True)

# %%
df.head()
# Out:
#        DEPTH        AC     CALI     DEN       GR      NEU    RDEP    RMED
# 0  3615.4340   95.7952  12.7249  2.3429  54.8754  44.5742  0.8941  0.8359
# 1  3615.5864   94.2267  12.5961  2.3528  53.5158  62.1103  0.7367  0.8028
# 2  3615.7388  101.3254  13.7632  2.3170  48.9803  71.9087  0.6423  0.7958
# 3  3615.8912   99.5672  14.3249  2.2585  36.6762  44.8988  0.6571  0.7929
# 4  3616.0436  100.5965  11.1429  2.2108  40.4632  49.5744  0.7442  0.7940

# %%
df.plot('GR', 'DEPTH')
# Out:
# <AxesSubplot:xlabel='GR'>

# %%
df.plot(subplots = True, figsize = (15, 15))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %% [markdown]
# ## Edito las graficas para visualizarlas verticalmente

# %% [markdown]
# ### Analizo una columna inicialmente, en este caso 'GR'

# %%
fig = plt.subplots(figsize = (10, 10))

ax1 = plt.subplot2grid((1, 1), (0, 0), rowspan = 1, colspan = 1)

ax1.plot('GR', 'DEPTH', data = df, color = 'green')
ax1.set_xlabel('Gamma')
ax1.set_xlim(0, 200)
ax1.set_ylim(4700, 3500)
ax1.grid()

# %% [markdown]
# ### Integro la curva de resistividad

# %%
fig = plt.subplots(figsize = (10, 10))

ax1 = plt.subplot2grid((1, 2), (0, 0), rowspan = 1, colspan = 1)
ax2 = plt.subplot2grid((1, 2), (0, 1), rowspan = 1, colspan = 1)


ax1.plot('GR', 'DEPTH', data = df, color = 'green')
ax1.set_xlabel('Gamma')
ax1.set_xlim(0, 200)
ax1.set_ylim(4700, 3500)
ax1.grid()

ax2.plot('RDEP', 'DEPTH', data = df, color = 'red')
ax2.set_xlabel('Deep Res.')
ax2.set_xlim(0.2, 2000)
ax2.semilogx()
ax2.set_ylim(4700, 3500)
ax2.grid()

# %% [markdown]
# ### Integro la curva de densidad

# %%
fig = plt.subplots(figsize = (10, 10))

ax1 = plt.subplot2grid((1, 3), (0, 0), rowspan = 1, colspan = 1)
ax2 = plt.subplot2grid((1, 3), (0, 1), rowspan = 1, colspan = 1)
ax3 = plt.subplot2grid((1, 3), (0, 2), rowspan = 1, colspan = 1)

ax1.plot('GR', 'DEPTH', data = df, color = 'green')
ax1.set_xlabel('Gamma')
ax1.set_xlim(0, 200)
ax1.set_ylim(4700, 3500)
ax1.grid()

ax2.plot('RDEP', 'DEPTH', data = df, color = 'blue')
ax2.set_xlabel('Deep Res.')
ax2.set_xlim(0.2, 2000)
ax2.semilogx()
ax2.set_ylim(4700, 3500)
ax2.grid()

ax3.plot('DEN', 'DEPTH', data = df, color = 'red')
ax3.set_xlabel('Density')
ax3.set_xlim(1.95, 2.95)
ax3.set_ylim(4700, 3500)
ax3.grid()

# %% [markdown]
# ### Edito los ejes

# %%
fig, axes = plt.subplots(figsize = (10, 10))

curve_names = ['Gamma', 'Deep Res', 'Density']

ax1 = plt.subplot2grid((1, 3), (0, 0), rowspan = 1, colspan = 1)
ax2 = plt.subplot2grid((1, 3), (0, 1), rowspan = 1, colspan = 1)
ax3 = plt.subplot2grid((1, 3), (0, 2), rowspan = 1, colspan = 1)

ax1.plot('GR', 'DEPTH', data = df, color = 'green')
ax1.set_xlim(0, 200)


ax2.plot('RDEP', 'DEPTH', data = df, color = 'blue')
ax2.set_xlim(0.2, 2000)
ax2.semilogx()


ax3.plot('DEN', 'DEPTH', data = df, color = 'red')
ax3.set_xlim(1.95, 2.95)

for i, ax in enumerate(fig.axes):
    ax.set_ylim(4700, 3500)
    ax.grid()
    ax.set_xlabel(curve_names[i])

# %%
fig, axes = plt.subplots(figsize = (10, 10))

curve_names = ['Gamma', 'Deep Res', 'Density']

ax1 = plt.subplot2grid((1, 3), (0, 0), rowspan = 1, colspan = 1)
ax2 = plt.subplot2grid((1, 3), (0, 1), rowspan = 1, colspan = 1)
ax3 = plt.subplot2grid((1, 3), (0, 2), rowspan = 1, colspan = 1)

ax1.plot('GR', 'DEPTH', data = df, color = 'green')
ax1.set_xlim(0, 200)


ax2.plot('RDEP', 'DEPTH', data = df, color = 'blue')
ax2.set_xlim(0.2, 2000)
ax2.semilogx()


ax3.plot('DEN', 'DEPTH', data = df, color = 'red')
ax3.set_xlim(1.95, 2.95)

for i, ax in enumerate(fig.axes):
    ax.set_ylim(4700, 3500)
    ax.grid()
    ax.set_xlabel(curve_names[i])
    
for ax in [ax2, ax3]:
    plt.setp(ax.get_yticklabels(), visible = False)
    
fig.subplots_adjust(wspace = 0.05)

# %% [markdown]
# ### Integro al perfil de densidad el de neutron e integro todo en mismo grafico

# %%
fig, axes = plt.subplots(figsize = (10, 10))

curve_names = ['Gamma', 'Deep Res', 'Density', 'Neutron']

ax1 = plt.subplot2grid((1, 3), (0, 0), rowspan = 1, colspan = 1)
ax2 = plt.subplot2grid((1, 3), (0, 1), rowspan = 1, colspan = 1)
ax3 = plt.subplot2grid((1, 3), (0, 2), rowspan = 1, colspan = 1)
ax4 = ax3.twiny()

ax1.plot('GR', 'DEPTH', data = df, color = 'green', lw =0.5)
ax1.set_xlim(0, 200)


ax2.plot('RDEP', 'DEPTH', data = df, color = 'blue', lw =0.5)
ax2.set_xlim(0.2, 2000)
ax2.semilogx()


ax3.plot('DEN', 'DEPTH', data = df, color = 'red',lw =0.5)
ax3.set_xlim(1.95, 2.95)

ax4.plot('NEU', 'DEPTH', data = df, color = 'grey',lw =0.5)
ax4.set_xlim(45, -15)

for i, ax in enumerate(fig.axes):
    ax.set_ylim(4700, 3500)
   
    ax.xaxis.set_ticks_position("top")
    ax.xaxis.set_label_position("top")
    ax.set_xlabel(curve_names[i])
    
    if i == 3:
        ax.spines["top"].set_position(("axes", 1.08))
    else:
        ax.grid()
    
    
for ax in [ax2, ax3]:
    plt.setp(ax.get_yticklabels(), visible = False)
    
fig.subplots_adjust(wspace = 0.05)

# %% [markdown]
# Lo que se quizo lograr es la visualizar los perfiles mas utilizados en la idustria
